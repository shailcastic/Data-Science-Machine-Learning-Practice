# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\SHAILESH TIWARI'

# %%
os.chdir('I:\\New\\hungary_chickenpox time series continuous rehression variable')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('hungary_chickenpox.csv')

# %%
dataset.head(10)
# Out:
#          Date  BUDAPEST  BARANYA  BACS  BEKES  BORSOD  CSONGRAD  FEJER  GYOR  \
# 0  03/01/2005       168       79    30    173     169        42    136   120
# 1  10/01/2005       157       60    30     92     200        53     51    70
# 2  17/01/2005        96       44    31     86      93        30     93    84
# 3  24/01/2005       163       49    43    126      46        39     52   114
# 4  31/01/2005       122       78    53     87     103        34     95   131
# 5  07/02/2005       174       76    77    152     189        26     74   181
# 6  14/02/2005       153      103    54    192     148        65    100   118
# 7  21/02/2005       115       74    64    174     140        56    111   175
# 8  28/02/2005       119       86    57    171      90        65    118   105
# 9  07/03/2005       114       81   129    217     167        64     93   154
#
#    HAJDU  ...  JASZ  KOMAROM  NOGRAD  PEST  SOMOGY  SZABOLCS  TOLNA  VAS  \
# ...

# %%
dataset.columns
# Out:
# Index(['Date', 'BUDAPEST', 'BARANYA', 'BACS', 'BEKES', 'BORSOD', 'CSONGRAD',
#        'FEJER', 'GYOR', 'HAJDU', 'HEVES', 'JASZ', 'KOMAROM', 'NOGRAD', 'PEST',
#        'SOMOGY', 'SZABOLCS', 'TOLNA', 'VAS', 'VESZPREM', 'ZALA'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      522 non-null    object
#  1   BUDAPEST  522 non-null    int64
#  2   BARANYA   522 non-null    int64
#  3   BACS      522 non-null    int64
#  4   BEKES     522 non-null    int64
#  5   BORSOD    522 non-null    int64
#  6   CSONGRAD  522 non-null    int64
#  7   FEJER     522 non-null    int64
#  8   GYOR      522 non-null    int64
#  9   HAJDU     522 non-null    int64
#  10  HEVES     522 non-null    int64
#  11  JASZ      522 non-null    int64
#  12  KOMAROM   522 non-null    int64
#  13  NOGRAD    522 non-null    int64
#  14  PEST      522 non-null    int64
#  15  SOMOGY    522 non-null    int64
#  16  SZABOLCS  522 non-null    int64
#  17  TOLNA     522 non-null    int64
#  18  VAS       522 non-null    int64
#  19  VESZPREM  522 non-null    int64
# ...

# %%
dataset.describe()
# Out:
#          BUDAPEST     BARANYA        BACS       BEKES      BORSOD    CSONGRAD  \
# count  522.000000  522.000000  522.000000  522.000000  522.000000  522.000000
# mean   101.245211   34.204981   37.166667   28.911877   57.082375   31.488506
# std     76.354872   32.567222   36.843095   37.618092   50.725437   33.790208
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     34.250000    8.000000    8.000000    4.000000   14.250000    6.000000
# 50%     93.000000   25.000000   29.500000   14.000000   46.500000   20.500000
# 75%    149.000000   51.000000   53.000000   38.750000   83.750000   47.000000
# max    479.000000  194.000000  274.000000  271.000000  355.000000  199.000000
#
#             FEJER        GYOR       HAJDU       HEVES        JASZ     KOMAROM  \
# count  522.000000  522.000000  522.000000  522.000000  522.000000  522.000000
# mean    33.272031   41.436782   47.097701   29.691571   40.869732   25.643678
# ...

# %%
dataset.isnull().sum()
# Out:
# Date        0
# BUDAPEST    0
# BARANYA     0
# BACS        0
# BEKES       0
# BORSOD      0
# CSONGRAD    0
# FEJER       0
# GYOR        0
# HAJDU       0
# HEVES       0
# JASZ        0
# KOMAROM     0
# NOGRAD      0
# PEST        0
# SOMOGY      0
# SZABOLCS    0
# TOLNA       0
# VAS         0
# VESZPREM    0
# ZALA        0
# dtype: int64

# %%
dataset['BUDAPEST'].plot()

# %%
dataset['BARANYA'].plot()

# %%
import seaborn as sns
sns.boxplot(y='BUDAPEST', data=dataset)

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset[['Date','VAS','ZALA','TOLNA']]

# %%
from pandas_profiling import ProfileReport

# %%
#generate a report
profile=ProfileReport(dataset)
profile.to_file(output_file="chickenpox.html")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      522 non-null    object
#  1   BUDAPEST  522 non-null    int64
#  2   BARANYA   522 non-null    int64
#  3   BACS      522 non-null    int64
#  4   BEKES     522 non-null    int64
#  5   BORSOD    522 non-null    int64
#  6   CSONGRAD  522 non-null    int64
#  7   FEJER     522 non-null    int64
#  8   GYOR      522 non-null    int64
#  9   HAJDU     522 non-null    int64
#  10  HEVES     522 non-null    int64
#  11  JASZ      522 non-null    int64
#  12  KOMAROM   522 non-null    int64
#  13  NOGRAD    522 non-null    int64
#  14  PEST      522 non-null    int64
#  15  SOMOGY    522 non-null    int64
#  16  SZABOLCS  522 non-null    int64
#  17  TOLNA     522 non-null    int64
#  18  VAS       522 non-null    int64
#  19  VESZPREM  522 non-null    int64
# ...

# %%
dataset.shape
# Out:
# (522, 21)

# %%
dataset.plot(subplots=True,x='Date',figsize=(15,35))
# plt.legend(loc='upper right')
plt.plot()
# Out:
# []

# %%
dataset.mean().sort_values().plot(kind ='barh')

print('Plotting the mean value shows that Budapest and Pest counties lead the list of mean cases')
# Out:
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Plotting the mean value shows that Budapest and Pest counties lead the list of mean cases

# %%
#Analyzing Time Series trendlines to shows seasonality in Budapest county
dataset = dataset.iloc[:,:2]
dataset.head()
# Out:
#          Date  BUDAPEST
# 0  03/01/2005       168
# 1  10/01/2005       157
# 2  17/01/2005        96
# 3  24/01/2005       163
# 4  31/01/2005       122

# %%
data_set.isnull().sum()

# %%
dataset['Time'] = pd.to_datetime(dataset['Date'])
dataset.head()
# Out:
#          Date  BUDAPEST       Time
# 0  03/01/2005       168 2005-03-01
# 1  10/01/2005       157 2005-10-01
# 2  17/01/2005        96 2005-01-17
# 3  24/01/2005       163 2005-01-24
# 4  31/01/2005       122 2005-01-31

# %%
dataset.isnull().sum()
# Out:
# Date        0
# BUDAPEST    0
# Time        0
# dtype: int64

# %%
dataset['Time'] = pd.to_datetime(dataset['Date'])
dataset.head()
# Out:
#          Date  BUDAPEST       Time
# 0  03/01/2005       168 2005-03-01
# 1  10/01/2005       157 2005-10-01
# 2  17/01/2005        96 2005-01-17
# 3  24/01/2005       163 2005-01-24
# 4  31/01/2005       122 2005-01-31

# %%
dataset = dataset.set_index('Time')
dataset.dtypes
# Out:
# Date        object
# BUDAPEST     int64
# dtype: object

# %%
dataset.plot(grid ='True')

# %%
dataset['Date'] = pd.to_datetime(dataset['Date'])

# %%
dataset.info()

# %%
dataset.set_index('Date', inplace= True)

# %%
dataset

# %%
dataset['BUDAPEST'].plot()

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
dataset.columns

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(dataset['BUDAPEST'], period=12)
decomposition.plot()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(dataset['BUDAPEST'])
# Out:
# (-6.933218014746714,
#  1.0708269234620812e-09,
#  12,
#  509,
#  {'1%': -3.443262740636999,
#   '5%': -2.8672350350046787,
#   '10%': -2.569803239025633},
#  5401.555790619231)

# %%
def adf_check(time_series):  #fi=unction for beter visual results
    result = adfuller(time_series)
    print("AUGMENTED DICKEY FULLER TEST")
    labels = ['ADF Test Statistic','P-value','#Lags','No of obs']
    for value,label in zip(result,labels):
        print(label + ':' + str(value))
    if result[1]<=0.05:
        print("time series is stationary")
    else:
        print("time series is not stationary")

# %%
adf_check(dataset['BUDAPEST'])
# Out:
# AUGMENTED DICKEY FULLER TEST
# ADF Test Statistic:-6.933218014746714
# P-value:1.0708269234620812e-09
# #Lags:12
# No of obs:509
# time series is stationary

# %%
#dataset['BUDAPEST first diff']=dataset['BUDAPEST']-dataset['BUDAPEST'].shift(1) # taking the difference of the data

# %%
#adf_check(dataset['BUDAPEST first diff'].dropna())

# %%
#time series is stationary
dataset['Chickenpox diff']=dataset['BUDAPEST']-dataset['BUDAPEST'].shift(12)

# %%
dataset
# Out:
#                   Date  BUDAPEST  Chickenpox diff
# Time
# 2005-03-01  03/01/2005       168              NaN
# 2005-10-01  10/01/2005       157              NaN
# 2005-01-17  17/01/2005        96              NaN
# 2005-01-24  24/01/2005       163              NaN
# 2005-01-31  31/01/2005       122              NaN
# ...                ...       ...              ...
# 2014-01-12  01/12/2014        95             85.0
# 2014-08-12  08/12/2014        43             32.0
# 2014-12-15  15/12/2014        35             19.0
# 2014-12-22  22/12/2014        30             10.0
# 2014-12-29  29/12/2014       259            242.0
#
# [522 rows x 3 columns]

# %%
dataset.to_csv('season output.csv')

# %%
adf_check(dataset['Chickenpox diff'].dropna())
# Out:
# AUGMENTED DICKEY FULLER TEST
# ADF Test Statistic:-5.94166816051302
# P-value:2.2533527625482663e-07
# #Lags:14
# No of obs:495
# time series is stationary

# %%
#D=1

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
plot_pacf(dataset['Chickenpox diff'].dropna(),lags=14)
