# %%
import os
os.chdir("I:\\New")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('World Indicators.xlsx')

# %%
data.head()
# Out:
#    Birth Rate  Business Tax Rate  CO2 Emissions       Country  \
# 0       0.020                NaN        87931.0       Algeria
# 1       0.050                NaN         9542.0        Angola
# 2       0.043                NaN         1617.0         Benin
# 3       0.027                NaN         4276.0      Botswana
# 4       0.046                NaN         1041.0  Burkina Faso
#
#    Days to Start Business  Ease of Business  Energy Usage           GDP  \
# 0                     NaN               NaN       26998.0  5.479006e+10
# 1                     NaN               NaN        7499.0  9.129595e+09
# 2                     NaN               NaN        1983.0  2.359122e+09
# 3                     NaN               NaN        1836.0  5.788312e+09
# 4                     NaN               NaN           NaN  2.610959e+09
#
#    Health Exp % GDP  Health Exp/Capita  ...  Number of Records  \
# 0             0.035               60.0  ...                  1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2704 entries, 0 to 2703
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Birth Rate              2585 non-null   float64
#  1   Business Tax Rate       1423 non-null   float64
#  2   CO2 Emissions           2125 non-null   float64
#  3   Country                 2704 non-null   object
#  4   Days to Start Business  1718 non-null   float64
#  5   Ease of Business        185 non-null    float64
#  6   Energy Usage            1785 non-null   float64
#  7   GDP                     2494 non-null   float64
#  8   Health Exp % GDP        2395 non-null   float64
#  9   Health Exp/Capita       2395 non-null   float64
#  10  Hours to do Tax         1416 non-null   float64
#  11  Infant Mortality Rate   2444 non-null   float64
#  12  Internet Usage          2531 non-null   float64
#  13  Lending Interest        1880 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# Birth Rate                 119
# Business Tax Rate         1281
# CO2 Emissions              579
# Country                      0
# Days to Start Business     986
# Ease of Business          2519
# Energy Usage               919
# GDP                        210
# Health Exp % GDP           309
# Health Exp/Capita          309
# Hours to do Tax           1288
# Infant Mortality Rate      260
# Internet Usage             173
# Lending Interest           824
# Life Expectancy Female     136
# Life Expectancy Male       136
# Mobile Phone Usage         167
# Number of Records            0
# Population 0-14            220
# Population 15-64           220
# Population 65+             220
# Population Total             0
# Population Urban            26
# Region                       0
# Tourism Inbound            368
# Tourism Outbound           482
# Year                         0
# dtype: int64

# %%
data.shape
# Out:
# (2704, 27)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=2704, step=1)

# %%
data.columns
# Out:
# Index(['Birth Rate', 'Business Tax Rate', 'CO2 Emissions', 'Country',
#        'Days to Start Business', 'Ease of Business', 'Energy Usage', 'GDP',
#        'Health Exp % GDP', 'Health Exp/Capita', 'Hours to do Tax',
#        'Infant Mortality Rate', 'Internet Usage', 'Lending Interest',
#        'Life Expectancy Female', 'Life Expectancy Male', 'Mobile Phone Usage',
#        'Number of Records', 'Population 0-14', 'Population 15-64',
#        'Population 65+', 'Population Total', 'Population Urban', 'Region',
#        'Tourism Inbound', 'Tourism Outbound', 'Year'],
#       dtype='object')

# %%
data.columns=['Birth_Rate', 'Business_Tax_Rate', 'CO2_Emissions', 'Country',
       'Days_to_Start Business', 'Ease_of_Business', 'Energy_Usage', 'GDP',
       'Health_Exp%_GDP', 'Health_Exp/Capita', 'Hours_todo_Tax',
       'Infant_Mortality_Rate', 'Internet_Usage', 'Lending_Interest',
       'Life_Expectancy_Female', 'Life_Expectancy_Male', 'Mobile_Phone_Usage',
       'Numberof_Records', 'Population0-14', 'Population15-64',
       'Population65+', 'Population_Total', 'Population_Urban', 'Region',
       'Tourism_Inbound', 'Tourism_Outbound', 'Year']

# %%
data.columns
# Out:
# Index(['Birth_Rate', 'Business_Tax_Rate', 'CO2_Emissions', 'Country',
#        'Days_to_Start Business', 'Ease_of_Business', 'Energy_Usage', 'GDP',
#        'Health_Exp%_GDP', 'Health_Exp/Capita', 'Hours_todo_Tax',
#        'Infant_Mortality_Rate', 'Internet_Usage', 'Lending_Interest',
#        'Life_Expectancy_Female', 'Life_Expectancy_Male', 'Mobile_Phone_Usage',
#        'Numberof_Records', 'Population0-14', 'Population15-64',
#        'Population65+', 'Population_Total', 'Population_Urban', 'Region',
#        'Tourism_Inbound', 'Tourism_Outbound', 'Year'],
#       dtype='object')

# %%
start_date = "01-12-2006"  #filtering dates from data
end_date = "01-12-2012"

after_start_date = data["Year"] >= start_date
before_end_date = data["Year"] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates = data.loc[between_two_dates]

print(filtered_dates)
# Out:
#       Birth_Rate  Business_Tax_Rate  CO2_Emissions                   Country  \
# 1248       0.022              0.769       103963.0                   Algeria
# 1249       0.049              0.521        22266.0                    Angola
# 1250       0.040              0.757         3876.0                     Benin
# 1251       0.025              0.171         4646.0                  Botswana
# 1252       0.044              0.476         1360.0              Burkina Faso
# ...          ...                ...            ...                       ...
# 2491         NaN                NaN            NaN  Turks and Caicos Islands
# 2492       0.013              0.465            NaN             United States
# 2493       0.015              0.419            NaN                   Uruguay
# 2494       0.020              0.628            NaN             Venezuela, RB
# 2495       0.011                NaN            NaN     Virgin Islands (U.S.)
#
# ...

# %%
data['Country'].value_counts() # counting the categorical data
# Out:
# Algeria                  13
# Angola                   13
# Turkey                   13
# Ukraine                  13
# United Kingdom           13
#                          ..
# Malaysia                 13
# Maldives                 13
# Mongolia                 13
# Myanmar                  13
# Virgin Islands (U.S.)    13
# Name: Country, Length: 208, dtype: int64

# %%
data['Region'].value_counts() # counting the categorical data
# Out:
# Africa          689
# Europe          624
# The Americas    585
# Asia            442
# Oceania         195
# Middle East     169
# Name: Region, dtype: int64

# %%
data.shape
# Out:
# (2704, 27)

# %%
data[data['Region']=='Africa']
# Out:
#       Birth_Rate  Business_Tax_Rate  CO2_Emissions       Country  \
# 0          0.020                NaN        87931.0       Algeria
# 1          0.050                NaN         9542.0        Angola
# 2          0.043                NaN         1617.0         Benin
# 3          0.027                NaN         4276.0      Botswana
# 4          0.046                NaN         1041.0  Burkina Faso
# ...          ...                ...            ...           ...
# 2544       0.037              0.489            NaN          Togo
# 2545       0.019              0.624            NaN       Tunisia
# 2546       0.044              0.366            NaN        Uganda
# 2547       0.043              0.151            NaN        Zambia
# 2548       0.032              0.345            NaN      Zimbabwe
#
#       Days_to_Start Business  Ease_of_Business  Energy_Usage           GDP  \
# 0                        NaN               NaN       26998.0  5.479006e+10
# ...

# %%
data[(data['Region']=='Africa') & (data['Country']=='Algeria')]
# Out:
#       Birth_Rate  Business_Tax_Rate  CO2_Emissions  Country  \
# 0          0.020                NaN        87931.0  Algeria
# 208        0.019                NaN        84293.0  Algeria
# 416        0.019                NaN        90854.0  Algeria
# 624        0.020                NaN        92533.0  Algeria
# 832        0.020                NaN        89493.0  Algeria
# 1040       0.021              0.769       107128.0  Algeria
# 1248       0.022              0.769       103963.0  Algeria
# 1456       0.023              0.742       112339.0  Algeria
# 1664       0.024              0.738       114619.0  Algeria
# 1872       0.024              0.720       124586.0  Algeria
# 2080       0.025              0.720       123475.0  Algeria
# 2288       0.025              0.720            NaN  Algeria
# 2496       0.025              0.719            NaN  Algeria
#
#       Days_to_Start Business  Ease_of_Business  Energy_Usage           GDP  \
# ...

# %%
data.groupby(['Region','Country']).size()
# Out:
# Region        Country
# Africa        Algeria                     13
#               Angola                      13
#               Benin                       13
#               Botswana                    13
#               Burkina Faso                13
#                                           ..
# The Americas  Turks and Caicos Islands    13
#               United States               13
#               Uruguay                     13
#               Venezuela, RB               13
#               Virgin Islands (U.S.)       13
# Length: 208, dtype: int64

# %%
data[data['Region'].isin(['Africa','Europe'])]
# Out:
#       Birth_Rate  Business_Tax_Rate  CO2_Emissions         Country  \
# 0          0.020                NaN        87931.0         Algeria
# 1          0.050                NaN         9542.0          Angola
# 2          0.043                NaN         1617.0           Benin
# 3          0.027                NaN         4276.0        Botswana
# 4          0.046                NaN         1041.0    Burkina Faso
# ...          ...                ...            ...             ...
# 2626       0.012              0.520            NaN          Sweden
# 2627       0.010              0.291            NaN     Switzerland
# 2628       0.017              0.400            NaN          Turkey
# 2629       0.011              0.554            NaN         Ukraine
# 2630       0.013              0.350            NaN  United Kingdom
#
#       Days_to_Start Business  Ease_of_Business  Energy_Usage           GDP  \
# 0                        NaN               NaN       26998.0  5.479006e+10
# ...

# %%
data['MyCalc']=data.Birth_Rate/data.Energy_Usage #creating a new column to multiply sense columns

# %%
data
# Out:
#       Birth_Rate  Business_Tax_Rate  CO2_Emissions                   Country  \
# 0          0.020                NaN        87931.0                   Algeria
# 1          0.050                NaN         9542.0                    Angola
# 2          0.043                NaN         1617.0                     Benin
# 3          0.027                NaN         4276.0                  Botswana
# 4          0.046                NaN         1041.0              Burkina Faso
# ...          ...                ...            ...                       ...
# 2699         NaN                NaN            NaN  Turks and Caicos Islands
# 2700       0.013              0.464            NaN             United States
# 2701       0.015              0.419            NaN                   Uruguay
# 2702       0.020              0.619            NaN             Venezuela, RB
# 2703       0.011                NaN            NaN     Virgin Islands (U.S.)
#
# ...

# %%
data.sort_values(['MyCalc'],ascending=1)
# Out:
#       Birth_Rate  Business_Tax_Rate  CO2_Emissions                   Country  \
# 2348       0.012              0.635            NaN                     China
# 2140       0.012              0.635      8286892.0                     China
# 1932       0.012              0.638      7692211.0                     China
# 1724       0.012              0.799      7035444.0                     China
# 2284       0.013              0.465      5433057.0             United States
# ...          ...                ...            ...                       ...
# 2698       0.015              0.291            NaN       Trinidad and Tobago
# 2699         NaN                NaN            NaN  Turks and Caicos Islands
# 2701       0.015              0.419            NaN                   Uruguay
# 2702       0.020              0.619            NaN             Venezuela, RB
# 2703       0.011                NaN            NaN     Virgin Islands (U.S.)
#
# ...

# %%
data[data.Population_Urban<0.500]
# Out:
#       Birth_Rate  Business_Tax_Rate  CO2_Emissions  \
# 1          0.050                NaN         9542.0
# 2          0.043                NaN         1617.0
# 4          0.046                NaN         1041.0
# 5          0.042                NaN          301.0
# 6          0.041                NaN         3432.0
# ...          ...                ...            ...
# 2682       0.021              0.359            NaN
# 2693         NaN              0.519            NaN
# 2694       0.016              0.346            NaN
# 2696       0.017              0.387            NaN
# 2698       0.015              0.291            NaN
#
#                              Country  Days_to_Start Business  \
# 1                             Angola                     NaN
# 2                              Benin                     NaN
# 4                       Burkina Faso                     NaN
# 5                            Burundi                     NaN
# ...

# %%
data.Country.unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Burundi', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.', "Cote d'Ivoire",
#        'Djibouti', 'Egypt, Arab Rep.', 'Equatorial Guinea', 'Eritrea',
#        'Ethiopia', 'Gabon', 'Gambia, The', 'Ghana', 'Guinea',
#        'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Swaziland',
#        'Tanzania', 'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe',
#        'Afghanistan', 'Armenia', 'Azerbaijan', 'Bangladesh', 'Bhutan',
#        'Brunei Darussalam', 'Cambodia', 'China', 'Georgia',
#        'Hong Kong SAR, China', 'India', 'Indonesia', 'Japan',
# ...

# %%
#data[(data['Business_Tax_Rate']>0.500) | (data|['Population_Urban']>0.200)]

# %%
plt.figure(figsize=(12,5))
sns.lmplot(data=data,x='CO2_Emissions',y='Energy_Usage',fit_reg=False,col='Region') #seperate for all income category

# %%
sns.lmplot(data=data,x="Birth_Rate",y='Energy_Usage')  # plotting a graph with seaborn

# %%
sns.lmplot(data=data,x="Birth_Rate",y='CO2_Emissions')

# %%
sns.lmplot(data=data,x="Ease_of_Business",y='Energy_Usage')

# %%
sns.lmplot(data=data,x="Birth_Rate",y='Population_Total')

# %%
sns.lmplot(data=data,x="Health_Exp%_GDP",y='Life_Expectancy_Male')

# %%
data.columns
# Out:
# Index(['Birth_Rate', 'Business_Tax_Rate', 'CO2_Emissions', 'Country',
#        'Days_to_Start Business', 'Ease_of_Business', 'Energy_Usage', 'GDP',
#        'Health_Exp%_GDP', 'Health_Exp/Capita', 'Hours_todo_Tax',
#        'Infant_Mortality_Rate', 'Internet_Usage', 'Lending_Interest',
#        'Life_Expectancy_Female', 'Life_Expectancy_Male', 'Mobile_Phone_Usage',
#        'Numberof_Records', 'Population0-14', 'Population15-64',
#        'Population65+', 'Population_Total', 'Population_Urban', 'Region',
#        'Tourism_Inbound', 'Tourism_Outbound', 'Year', 'MyCalc'],
#       dtype='object')

# %%
sns.lmplot(data=data,x="Health_Exp%_GDP",y='Population_Total')

# %%
data.isnull().sum()
# Out:
# Birth_Rate                 119
# Business_Tax_Rate         1281
# CO2_Emissions              579
# Country                      0
# Days_to_Start Business     986
# Ease_of_Business          2519
# Energy_Usage               919
# GDP                        210
# Health_Exp%_GDP            309
# Health_Exp/Capita          309
# Hours_todo_Tax            1288
# Infant_Mortality_Rate      260
# Internet_Usage             173
# Lending_Interest           824
# Life_Expectancy_Female     136
# Life_Expectancy_Male       136
# Mobile_Phone_Usage         167
# Numberof_Records             0
# Population0-14             220
# Population15-64            220
# Population65+              220
# Population_Total             0
# Population_Urban            26
# Region                       0
# Tourism_Inbound            368
# Tourism_Outbound           482
# Year                         0
# MyCalc                     927
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2704 entries, 0 to 2703
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Birth_Rate              2585 non-null   float64
#  1   Business_Tax_Rate       1423 non-null   float64
#  2   CO2_Emissions           2125 non-null   float64
#  3   Country                 2704 non-null   object
#  4   Days_to_Start Business  1718 non-null   float64
#  5   Ease_of_Business        185 non-null    float64
#  6   Energy_Usage            1785 non-null   float64
#  7   GDP                     2494 non-null   float64
#  8   Health_Exp%_GDP         2395 non-null   float64
#  9   Health_Exp/Capita       2395 non-null   float64
#  10  Hours_todo_Tax          1416 non-null   float64
#  11  Infant_Mortality_Rate   2444 non-null   float64
#  12  Internet_Usage          2531 non-null   float64
#  13  Lending_Interest        1880 non-null   float64
# ...

# %%
import seaborn as sns
sns.boxplot(y='Birth_Rate', data=data)

# %%
sns.boxplot(y='Birth_Rate', data=data)

# %%
sns.boxplot(y='Business_Tax_Rate', data=data)

# %%
sns.boxplot(y='CO2_Emissions', data=data)

# %%
sns.boxplot(y='Days_to_Start Business', data=data)

# %%
sns.boxplot(y='Hours_todo_Tax', data=data)

# %%
sns.boxplot(y='Life_Expectancy_Male', data=data)

# %%
sns.boxplot(y='Life_Expectancy_Female', data=data)

# %%
sns.boxplot(y='Mobile_Phone_Usage', data=data)

# %%
sns.boxplot(y='Population0-14', data=data)

# %%
sns.boxplot(y='Population15-64', data=data)

# %%
sns.boxplot(y='Population65+', data=data)

# %%
sns.boxplot(y='Population_Urban', data=data)

# %%
sns.boxplot(y='Tourism_Inbound', data=data)

# %%
sns.boxplot(y='Tourism_Outbound', data=data)

# %%
data.isnull().sum()
# Out:
# Birth_Rate                 119
# Business_Tax_Rate         1281
# CO2_Emissions              579
# Country                      0
# Days_to_Start Business     986
# Ease_of_Business          2519
# Energy_Usage               919
# GDP                        210
# Health_Exp%_GDP            309
# Health_Exp/Capita          309
# Hours_todo_Tax            1288
# Infant_Mortality_Rate      260
# Internet_Usage             173
# Lending_Interest           824
# Life_Expectancy_Female     136
# Life_Expectancy_Male       136
# Mobile_Phone_Usage         167
# Numberof_Records             0
# Population0-14             220
# Population15-64            220
# Population65+              220
# Population_Total             0
# Population_Urban            26
# Region                       0
# Tourism_Inbound            368
# Tourism_Outbound           482
# Year                         0
# MyCalc                     927
# dtype: int64

# %%
#data imputation
#calculation of percentage of missing data
total = data.isnull().sum().sort_values(ascending=False)
percent_1 = data.isnull().sum()/data.isnull().count()*100
percent_2 = (round(percent_1, 1)).sort_values(ascending=False)
missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
missing_data.head(25)
# Out:
#                         Total     %
# Ease_of_Business         2519  93.2
# Hours_todo_Tax           1288  47.6
# Business_Tax_Rate        1281  47.4
# Days_to_Start Business    986  36.5
# MyCalc                    927  34.3
# Energy_Usage              919  34.0
# Lending_Interest          824  30.5
# CO2_Emissions             579  21.4
# Tourism_Outbound          482  17.8
# Tourism_Inbound           368  13.6
# Health_Exp/Capita         309  11.4
# Health_Exp%_GDP           309  11.4
# Infant_Mortality_Rate     260   9.6
# Population15-64           220   8.1
# Population65+             220   8.1
# Population0-14            220   8.1
# GDP                       210   7.8
# Internet_Usage            173   6.4
# Mobile_Phone_Usage        167   6.2
# Life_Expectancy_Female    136   5.0
# Life_Expectancy_Male      136   5.0
# Birth_Rate                119   4.4
# Population_Urban           26   1.0
# Numberof_Records            0   0.0
# Population_Total            0   0.0

# %%
#housing.dropna(subset=['Ease_of_Business'])# option 1
data.drop(['Ease_of_Business','Hours_todo_Tax','Business_Tax_Rate','Days_to_Start Business'], axis=1)
# option 2
#median = housing["total_bedrooms"].median()
# option 3
#housing["total_bedrooms"].fillna(median, inplace=True)
# Out:
#       Birth_Rate  CO2_Emissions                   Country  Energy_Usage  \
# 0          0.020        87931.0                   Algeria       26998.0
# 1          0.050         9542.0                    Angola        7499.0
# 2          0.043         1617.0                     Benin        1983.0
# 3          0.027         4276.0                  Botswana        1836.0
# 4          0.046         1041.0              Burkina Faso           NaN
# ...          ...            ...                       ...           ...
# 2699         NaN            NaN  Turks and Caicos Islands           NaN
# 2700       0.013            NaN             United States     2132446.0
# 2701       0.015            NaN                   Uruguay           NaN
# 2702       0.020            NaN             Venezuela, RB           NaN
# 2703       0.011            NaN     Virgin Islands (U.S.)           NaN
#
#                GDP  Health_Exp%_GDP  Health_Exp/Capita  Infant_Mortality_Rate  \
# ...

# %%
import seaborn as sns
#
# Box plot
#
sns.boxplot(data.Energy_Usage)
#
# Distribution plot
#
sns.displot(data.Energy_Usage)
# Out:
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.distplot(data.Energy_Usage)
# Out:
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data.isnull().sum()
# Out:
# Birth_Rate                 119
# Business_Tax_Rate         1281
# CO2_Emissions              579
# Country                      0
# Days_to_Start Business     986
# Ease_of_Business          2519
# Energy_Usage               919
# GDP                        210
# Health_Exp%_GDP            309
# Health_Exp/Capita          309
# Hours_todo_Tax            1288
# Infant_Mortality_Rate      260
# Internet_Usage             173
# Lending_Interest           824
# Life_Expectancy_Female     136
# Life_Expectancy_Male       136
# Mobile_Phone_Usage         167
# Numberof_Records             0
# Population0-14             220
# Population15-64            220
# Population65+              220
# Population_Total             0
# Population_Urban            26
# Region                       0
# Tourism_Inbound            368
# Tourism_Outbound           482
# Year                         0
# MyCalc                     927
# dtype: int64

# %%
# option 3
data["Energy_Usage"].fillna(median, inplace=True)

# %%
data.isnull().sum()
# Out:
# Birth_Rate                 119
# Business_Tax_Rate         1281
# CO2_Emissions              579
# Country                      0
# Days_to_Start Business     986
# Ease_of_Business          2519
# Energy_Usage                 0
# GDP                        210
# Health_Exp%_GDP            309
# Health_Exp/Capita          309
# Hours_todo_Tax            1288
# Infant_Mortality_Rate      260
# Internet_Usage             173
# Lending_Interest           824
# Life_Expectancy_Female     136
# Life_Expectancy_Male       136
# Mobile_Phone_Usage         167
# Numberof_Records             0
# Population0-14             220
# Population15-64            220
# Population65+              220
# Population_Total             0
# Population_Urban            26
# Region                       0
# Tourism_Inbound            368
# Tourism_Outbound           482
# Year                         0
# MyCalc                     927
# dtype: int64

# %%
sns.distplot(data.Lending_Interest)
# Out:
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
missing_col=['Lending_Interest']        #missing value imputation using mean
for i in missing_col:
    data.loc[data.loc[:,i].isnull(),i]=data.loc[:,i].mean()

# %%
data.isnull().sum()
# Out:
# Birth_Rate                 119
# Business_Tax_Rate         1281
# CO2_Emissions              579
# Country                      0
# Days_to_Start Business     986
# Ease_of_Business          2519
# Energy_Usage                 0
# GDP                        210
# Health_Exp%_GDP            309
# Health_Exp/Capita          309
# Hours_todo_Tax            1288
# Infant_Mortality_Rate      260
# Internet_Usage             173
# Lending_Interest             0
# Life_Expectancy_Female     136
# Life_Expectancy_Male       136
# Mobile_Phone_Usage         167
# Numberof_Records             0
# Population0-14             220
# Population15-64            220
# Population65+              220
# Population_Total             0
# Population_Urban            26
# Region                       0
# Tourism_Inbound            368
# Tourism_Outbound           482
# Year                         0
# MyCalc                     927
# dtype: int64

# %%
sns.distplot(data.CO2_Emissions)
# Out:
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data["CO2_Emissions"].fillna(median, inplace=True)

# %%
data.isnull().sum()
# Out:
# Birth_Rate                 119
# Business_Tax_Rate         1281
# CO2_Emissions                0
# Country                      0
# Days_to_Start Business     986
# Ease_of_Business          2519
# Energy_Usage                 0
# GDP                        210
# Health_Exp%_GDP            309
# Health_Exp/Capita          309
# Hours_todo_Tax            1288
# Infant_Mortality_Rate      260
# Internet_Usage             173
# Lending_Interest             0
# Life_Expectancy_Female     136
# Life_Expectancy_Male       136
# Mobile_Phone_Usage         167
# Numberof_Records             0
# Population0-14             220
# Population15-64            220
# Population65+              220
# Population_Total             0
# Population_Urban            26
# Region                       0
# Tourism_Inbound            368
# Tourism_Outbound           482
# Year                         0
# MyCalc                     927
# dtype: int64
