# %%
import os
os.chdir("I:\\New")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('Green Valves.xlsx')

# %%
data.head()
# Out:
#    Annual Income Birth Date      Sales     profit Category Name  \
# 0          80000 1958-11-11   699.0982   285.9519         Bikes
# 1          80000 1955-04-11  3578.2700  1406.9758         Bikes
# 2         100000 1974-04-21  3374.9900  1476.8956         Bikes
# 3          30000 1980-09-25   699.0982   285.9519         Bikes
# 4          20000 1965-01-11  3578.2700  1406.9758         Bikes
#
#        Continent         Country  CustomerKey (AdventureWorks Customers.csv)  \
# 0  North America   United States                                       14657
# 1  North America   United States                                       29255
# 2        Pacific       Australia                                       11455
# 3  North America          Canada                                       26782
# 4         Europe  United Kingdom                                       14947
#
#    CustomerKey       Date  ... Product Style  \
# 0        14657 2015-01-01  ...             U
# ...

# %%
data.size
# Out:
# 1492792

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32452 entries, 0 to 32451
# Data columns (total 46 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Annual Income                                                     32452 non-null  int64
#  1   Birth Date                                                        32452 non-null  datetime64[ns]
#  2   Sales                                                             32452 non-null  float64
#  3   profit                                                            32452 non-null  float64
#  4   Category Name                                                     32452 non-null  object
#  5   Continent                                                         32452 non-null  object
#  6   Country                                                           32452 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# Annual Income                                                           0
# Birth Date                                                              0
# Sales                                                                   0
# profit                                                                  0
# Category Name                                                           0
# Continent                                                               0
# Country                                                                 0
# CustomerKey (AdventureWorks Customers.csv)                              0
# CustomerKey                                                             0
# Date                                                                    0
# Education Level                                                         0
# Email Address                                                           0
# First Name                                                              0
# ...

# %%
data.shape
# Out:
# (32452, 46)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=32452, step=1)

# %%
data.columns
# Out:
# Index(['Annual Income', 'Birth Date', 'Sales', 'profit', 'Category Name',
#        'Continent', 'Country', 'CustomerKey (AdventureWorks Customers.csv)',
#        'CustomerKey', 'Date', 'Education Level', 'Email Address', 'First Name',
#        'Gender', 'Home Owner', 'Last Name', 'Marital Status', 'Model Name',
#        'Number of Records', 'Occupation', 'OrderDate', 'OrderLineItem',
#        'OrderNumber', 'OrderQuantity', 'Prefix',
#        'ProductCategoryKey (AdventureWorks Product Categories.csv)',
#        'Product Category Key', 'Product Color', 'Product Cost',
#        'Product Description', 'ProductKey (AdventureWorks Products.csv)',
#        'ProductKey', 'Product Name', 'Product Price', 'Product SKU',
#        'Product Size', 'Product Style',
#        'ProductSubcategoryKey (AdventureWorks Product Subcategories.csv)',
#        'Product Subcategory Key', 'Region', 'Sales Territory Key', 'StockDate',
# ...

# %%
data.columns=['Annual_Income', 'Birth_Date', 'Sales', 'profit', 'Category_Name',
       'Continent', 'Country', 'CustomerKey','Customer_Key', 'Date', 'Education_Level', 'Email_Address', 'First_Name',
       'Gender', 'Home_Owner', 'Last_Name', 'Marital_Status', 'Model_Name',
       'Number_of_Records', 'Occupation', 'Order_Date', 'OrderLineItem',
       'OrderNumber', 'Order_Quantity', 'Prefix',
       'Product_CategoryKey',
       'Product_Category_Key', 'Product_Color', 'Product_Cost',
       'Product_Description', 'ProductKey',
       'ProductKey', 'Product_Name', 'Product_Price', 'Product_SKU',
       'Product_Size', 'Product_Style',
       'Product_Subcategory_Key',
       'Product_Subcategory_Key', 'Region', 'Sales_Territory_Key', 'Stock_Date',
       'Subcategory_Name', 'Table_Name', 'TerritoryKey', 'Total_Children']

# %%
data.columns
# Out:
# Index(['Annual_Income', 'Birth_Date', 'Sales', 'profit', 'Category_Name',
#        'Continent', 'Country', 'CustomerKey', 'Customer_Key', 'Date',
#        'Education_Level', 'Email_Address', 'First_Name', 'Gender',
#        'Home_Owner', 'Last_Name', 'Marital_Status', 'Model_Name',
#        'Number_of_Records', 'Occupation', 'Order_Date', 'OrderLineItem',
#        'OrderNumber', 'Order_Quantity', 'Prefix', 'Product_CategoryKey',
#        'Product_Category_Key', 'Product_Color', 'Product_Cost',
#        'Product_Description', 'ProductKey', 'ProductKey', 'Product_Name',
#        'Product_Price', 'Product_SKU', 'Product_Size', 'Product_Style',
#        'Product_Subcategory_Key', 'Product_Subcategory_Key', 'Region',
#        'Sales_Territory_Key', 'Stock_Date', 'Subcategory_Name', 'Table_Name',
#        'TerritoryKey', 'Total_Children'],
#       dtype='object')

# %%
data.Annual_Income.unique()
# Out:
# array([ 80000, 100000,  30000,  20000,  60000,  70000,  40000,  10000,
#        120000, 170000, 130000,  90000, 110000, 160000, 150000,  50000],
#       dtype=int64)

# %%
data.Marital_Status.unique()
# Out:
# array(['M', 'S'], dtype=object)

# %%
sns.lmplot(data=data,x="Sales",y='profit')

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Continent',y='profit',data=data, palette='rainbow')
plt.title("Continent wise profit showing,sales of valves")
# Out:
# Text(0.5, 1.0, 'Continent wise profit showing,sales of valves')

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Continent',y='Sales',data=data, palette='rainbow')
plt.title("Continent wise profit showing,sales of valves")
# Out:
# Text(0.5, 1.0, 'Continent wise profit showing,sales of valves')

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Continent',y='profit',data=data,hue= 'Country', palette='rainbow')
plt.title("Continent wise profit showing,sales of valves")
# Out:
# Text(0.5, 1.0, 'Continent wise profit showing,sales of valves')

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Continent',y='profit',data=data,hue= 'Category_Name', palette='rainbow')
plt.title("Continent wise profit showing,sales of valves")
# Out:
# Text(0.5, 1.0, 'Continent wise profit showing,sales of valves')

# %%
sns.lmplot(data=data,x="Annual_Income",y='Sales')

# %%
sns.lmplot(data=data,x="Annual_Income",y='profit')

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Education_Level',y='Annual_Income',data=data,hue= 'Category_Name', palette='rainbow')
plt.title("Continent wise profit showing,sales of valves")
# Out:
# Text(0.5, 1.0, 'Continent wise profit showing,sales of valves')

# %%
#plt.figure(figsize=(8,5))
sns.boxplot(x='Education_Level',y='Annual_Income',data=data, palette='rainbow')
plt.title("Continent wise profit showing,sales of valves")
# Out:
# Text(0.5, 1.0, 'Continent wise profit showing,sales of valves')

# %%
#plt.figure(figsize=(8,5))
sns.boxplot(x='Marital_Status',y='Annual_Income',data=data, palette='rainbow')
plt.title("Continent wise profit showing,sales of valves")
# Out:
# Text(0.5, 1.0, 'Continent wise profit showing,sales of valves')

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='Continent',y="Annual_Income",data=data, hue='Category_Name', palette='rainbow')
plt.title("Violin Plot of Age by Class, Separated by Sex")
# Out:
# Text(0.5, 1.0, 'Violin Plot of Age by Class, Separated by Sex')

# %%
#plt.figure(figsize=(10,6))
sns.violinplot(x='Continent',y="Annual_Income",data=data, hue='Gender',split='True',palette='rainbow')
plt.title("Violin Plot of Age by Class, Separated by Gender")
# Out:
# Text(0.5, 1.0, 'Violin Plot of Age by Class, Separated by Gender')

# %%
plt.figure(figsize=(8,5))
sns.boxenplot(x='Continent', y='Annual_Income', data=data, palette='rainbow')
plt.title("Distribution of Annual income across continent")
# Out:
# Text(0.5, 1.0, 'Distribution of Annual income across continent')

# %%
plt.figure(figsize=(8,5))
sns.boxenplot(x='Continent', y='Annual_Income', data=data, palette='rainbow', hue='Region')
plt.title("Distribution of Age by Passenger Class, Separated by Survival")
# Out:
# Text(0.5, 1.0, 'Distribution of Age by Passenger Class, Separated by Survival')

# %%
#Categorical Estimate Plots
#Bar plot
plt.figure(figsize=(12,5))
sns.barplot(x='Region',y='Annual_Income',data=data, palette='rainbow')
plt.title("Annual Income divided across region")
# Out:
# Text(0.5, 1.0, 'Annual Income divided across region')

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Occupation',y='Annual_Income',data=data, palette='rainbow', hue='Gender')
plt.title("Fare of Passenger by Embarked Town, Divided by Class")
# Out:
# Text(0.5, 1.0, 'Fare of Passenger by Embarked Town, Divided by Class')

# %%
#point plot
plt.figure(figsize=(8,5))
sns.pointplot(x='Occupation',y='Annual_Income',data=data)
plt.title("Average Fare Price by Embarked Town")
# Out:
# Text(0.5, 1.0, 'Average Fare Price by Embarked Town')

# %%
plt.figure(figsize=(8,5))
sns.pointplot(x='Occupation',y='Annual_Income',data=data, hue='Education_Level')
plt.title("Income distribution across occupation,Education Level")
# Out:
# Text(0.5, 1.0, 'Income distribution across occupation,Education Level')

# %%
#countplot
plt.figure(figsize=(8,5))
sns.countplot(x='Occupation',data=data, palette='rainbow')
plt.title("Count of Passengers that Embarked in Each City")
# Out:
# Text(0.5, 1.0, 'Count of Passengers that Embarked in Each City')

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Education_Level',data=data, palette='rainbow',hue='Gender')
plt.title("Count of Passengers that Embarked in Each City, Separated by Sex")
# Out:
# Text(0.5, 1.0, 'Count of Passengers that Embarked in Each City, Separated by Sex')

# %%
#Categorical Scatter Plots
#strip plot
plt.figure(figsize=(12,8))
sns.stripplot(x='Occupation', y='Annual_Income', data=data, jitter=True, hue='Gender', dodge=True, palette='viridis')

# %%
#Categorical Scatter Plots
#strip plot
plt.figure(figsize=(12,8))
sns.stripplot(x='Education_Level', y='Annual_Income', data=data, jitter=True, hue='Gender', dodge=True, palette='viridis')

# %%
#swarm plot
plt.figure(figsize=(14,7))
sns.swarmplot(x='Gender', y='Annual_Income', data=data, hue='Occupation', dodge=True, palette='viridis')
plt.title("Age by Passenger Class, Separated by Survival")
# Out:
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 97.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 96.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 95.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-ede73e9fbfe0> in <module>
#       1 #swarm plot
#       2 plt.figure(figsize=(14,7))
# ...

# %%
#combining plots
plt.figure(figsize=(12,8))
sns.violinplot(x='Education_Level',y="Annual_Income", data=data, hue='Gender', split='True', palette='rainbow')
sns.swarmplot(x='Education_Level',y="Annual_Income", data=data, hue='Gender', dodge='True', color='grey', alpha=.8, s=4)
plt.title("Age by Passenger Class, Separated by Survival")
# Out:
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 95.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 95.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 92.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 92.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='Occupation',y='Annual_Income',hue='Education_Level',data=data, palette='rainbow')
sns.swarmplot(x='Occupation',y='Annual_Income',hue='Education_Level', dodge=True,data=data, alpha=.8,color='grey',s=4)
plt.title("Age by Passenger Class, Separated by Survival")
# Out:
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 98.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 98.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 98.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\SHAILESH TIWARI\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 97.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
plt.figure(figsize=(12,7))
    sns.barplot(x='Occupation',y='Annual_Income',data=data, palette='rainbow', hue='Gender')
    sns.stripplot(x='Occupation',y="Annual_Income",data=data, hue='class', dodge='True', color='grey', alpha=.8, s=2)
plt.title("Fare of Passenger by Embarked Town, Divided by Class")

# %%
#Faceting Data with Catplot
g = sns.catplot(x='class',y='survived', col = 'who', data=titanic,
                kind='bar', aspect=.6, palette='Set2')
(g.set_axis_labels("Class", "Survival Rate")
  .set_titles("{col_name}")
  .set(ylim=(0,1)))
plt.tight_layout()
plt.savefig('seaborn_catplot.png', dpi=1000)
